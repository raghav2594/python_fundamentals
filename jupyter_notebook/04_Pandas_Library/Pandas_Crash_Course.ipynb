# %% [markdown]
# ### Chapter 1: Getting and Knowing your Data

# %%
import pandas as pd

# %%
order_details = pd.read_csv(filepath_or_buffer= "data.tsv.txt", sep="\t")
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
pd.read_table(filepath_or_buffer="insurance.csv", sep=",")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### 1.1 Perform Initial Analysis

# %%
# Function - ()
# Attribute

# %%
order_details.shape
# Out:
# (4622, 5)

# %% [markdown]
# #### Terminology Alert
# * Row - Observation/Record
# * Column - Features/Parameters

# %%
order_details.isnull() # Displays the table form and shows each record is null or not
# Out:
#       order_id  quantity  item_name  choice_description  item_price
# 0        False     False      False                True       False
# 1        False     False      False               False       False
# 2        False     False      False               False       False
# 3        False     False      False                True       False
# 4        False     False      False               False       False
# ...        ...       ...        ...                 ...         ...
# 4617     False     False      False               False       False
# 4618     False     False      False               False       False
# 4619     False     False      False               False       False
# 4620     False     False      False               False       False
# 4621     False     False      False               False       False
#
# [4622 rows x 5 columns]

# %%
order_details.isnull().sum() # Chain of Functions, Chain of Commands
# Summerise overall null details
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
order_details.describe( )
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
order_details.describe(include='all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 order_details.describe(include='all')
#
# NameError: name 'order_details' is not defined

# %% [markdown]
# ### 1.2 Find out the Items soldin the restaurant?

# %%
order_details.nunique() #Displays the each unique items count
# Out:
# order_id              1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
order_details["item_name"].nunique() # displays the individual data count
# Out:
# 50

# %%
order_details["item_name"].unique() # displays the list of unique items
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %% [markdown]
# ### 1.3 Give me the list of Top 5 selling Items

# %%
order_details.groupby(by = "item_name")["quantity"].sum().sort_values() #Displays all the items sold in howmuch quantity in assending order
# Out:
# item_name
# Carnitas Salad                             1
# Chips and Mild Fresh Tomato Salsa          1
# Veggie Crispy Tacos                        1
# Crispy Tacos                               2
# Salad                                      2
# Steak Salad                                4
# Bowl                                       4
# Burrito                                    6
# Carnitas Salad Bowl                        6
# Veggie Salad                               6
# Veggie Soft Tacos                          8
# Carnitas Crispy Tacos                      8
# Chicken Salad                              9
# Barbacoa Salad Bowl                       10
# Barbacoa Crispy Tacos                     12
# Chips and Roasted Chili-Corn Salsa        18
# Veggie Salad Bowl                         18
# Izze                                      20
# Chips and Roasted Chili Corn Salsa        23
# Barbacoa Soft Tacos                       25
# Chips and Tomatillo-Red Chili Salsa       25
# ...

# %%
order_details.groupby(by = "item_name")["quantity"].sum().sort_values(ascending=False) #Displays all the items sold in howmuch quantity in decending order

# %%
#display top 5 items maximum sold
order_details.groupby(by = "item_name")["quantity"].sum().sort_values(ascending=False).head(5)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %% [markdown]
# ### 1.4 Give me the list of least 5 selling Items

# %%
#display least 5 items maximum sold
order_details.groupby(by = "item_name")["quantity"].sum().sort_values().head(5)
#or
order_details.groupby(by = "item_name")["quantity"].sum().sort_values(ascending=False).tail(5)
# Out:
# item_name
# Salad                                2
# Crispy Tacos                         2
# Carnitas Salad                       1
# Chips and Mild Fresh Tomato Salsa    1
# Veggie Crispy Tacos                  1
# Name: quantity, dtype: int64

# %% [markdown]
# ## Chapter 2 - Data Cleaning
# * Remove '$' from item_price column

# %%
order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
order_details["item_price"]
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
order_details["item_price"].str.replace("$","").float()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14316\3971084785.py in ?()
# ----> 1 order_details["item_price"].str.replace("$","").float()
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'float'

# %%
order_details["item_price"].str.replace("$","").astype(float)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
order_details #Float conversion not happened
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
order_details["item_price"] = order_details["item_price"].str.replace("$","").astype(float)

# %%
order_details.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
order_details.describe()
# Out:
#           order_id     quantity   item_price
# count  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336
# std     528.890796     0.410186     4.245557
# min       1.000000     1.000000     1.090000
# 25%     477.250000     1.000000     3.390000
# 50%     926.000000     1.000000     8.750000
# 75%    1393.000000     1.000000     9.250000
# max    1834.000000    15.000000    44.250000

# %% [markdown]
# ## Task
#
# * Find out the top 5 selling items individual revenue it made
# * Total revenue of the top 5 items sold
# * Find atleast 2 more questions on the same dataset

# %% [markdown]
# ## Task 1 : Find Out the top 5 selling items  individual revenue

# %%
#order_details.groupby("item_name")["item_price"].sum().sort_values(ascending=False)
#order_details.groupby("item_name").first()
#My Solution
order_details.groupby("item_name").agg(
    quantity = ("quantity", "sum"),
    revenue = ("item_price", "sum")
).sort_values('quantity', ascending=False).head(5)
# Out:
#                      quantity  revenue
# item_name
# Chicken Bowl              761  7342.73
# Chicken Burrito           591  5575.82
# Chips and Guacamole       506  2201.04
# Steak Burrito             386  3851.43
# Canned Soft Drink         351   438.75

# %%
#Copilot suggested
top5 = (order_details.groupby('item_name', as_index=False).agg(
          total_quantity=('quantity', 'sum'),
          total_revenue=('item_price', 'sum')  # item_price is line total per row
           ).sort_values('total_quantity', ascending=False).head(5))

top5['total_revenue'] = top5['total_revenue'].map(lambda x: f"${x:,.2f}")
top5
# Out:
#               item_name  total_quantity total_revenue
# 17         Chicken Bowl             761     $7,342.73
# 18      Chicken Burrito             591     $5,575.82
# 25  Chips and Guacamole             506     $2,201.04
# 39        Steak Burrito             386     $3,851.43
# 10    Canned Soft Drink             351       $438.75

# %% [markdown]
# ## Task 2 : Find Out the top 5 selling items  total revenue

# %%
top5 = order_details.groupby("item_name", as_index=False).agg(
    quantity = ("quantity", "sum"),
    revenue = ("item_price", "sum")
).sort_values('quantity', ascending=False).head(5)
top5.agg(
    total_revenue = ("revenue","sum")
)
# Out:
#                 revenue
# total_revenue  19409.77

# %% [markdown]
# ## Task 3 : Make Question?
# How many orders in the given dataset is having minimum order value of 25$?

# %%
order_details[order_details["item_price"] > 25].sort_values("item_price", ascending=False)
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
# 409        178         3                  Chicken Bowl
# 3603      1443         3                 Steak Burrito
# 1255       511         3                 Steak Burrito
# 1514       616         3                  Chicken Bowl
# 3634      1454         3               Chicken Burrito
# 3636      1454         3               Chicken Burrito
# 3334      1336         3                    Steak Bowl
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25
# ...

# %% [markdown]
# ## Task 4 : Make Question?
# How many orders in the given dataset is having minimum order value of 10$ to 25$?

# %%
order_details[order_details["item_price"].isin([10,25])] #this will not work. it expects the paritcular entry
#we can use filter query
order_details.query("item_price > 10 and item_price < 25").sort_values("item_price")
# Out:
#       order_id  quantity         item_name  \
# 3599      1443         7     Bottled Water
# 2919      1160         1      Chicken Bowl
# 3520      1415         1   Chicken Burrito
# 1160       479         1   Chicken Burrito
# 1099       453         1   Chicken Burrito
# ...        ...       ...               ...
# 3754      1502         2        Steak Bowl
# 1753       708         2     Steak Burrito
# 1566       635         2        Steak Bowl
# 613        253         2  Steak Salad Bowl
# 281        123         2  Steak Salad Bowl
#
#                                      choice_description  item_price
# 3599                                                NaN       10.50
# 2919           [Fresh Tomato (Mild), [Guacamole, Rice]]       10.58
# 3520  [Fresh Tomato (Mild), [Guacamole, Rice, Sour C...       10.58
# 1160  [Fresh Tomato (Mild), [Guacamole, Rice, Fajita...       10.58
# 1099  [Fresh Tomato (Mild), [Guacamole, Lettuce, Ric...       10.58
# ...

# %% [markdown]
# ## Chapter 3 Pandas Data Structure
#
# * 1D - Series
# * 2D - DataFrame

# %%
pd.Series(data=(1,2,4.5,'$5.6'))
# Out:
# 0       1
# 1       2
# 2     4.5
# 3    $5.6
# dtype: object

# %%
student_data = {"Name": ["Raghav", "Nithya"],
               "age": [30,30]}
pd.DataFrame(data=(1,2,4.5,'$5.6'))
pd.DataFrame(data= student_data)
# Out:
#      Name  age
# 0  Raghav   30
# 1  Nithya   30

# %% [markdown]
# ## Chapter 4 : Filtering & Selection and Sorting

# %%
euro_2012_data = pd.read_csv("Euro_2012_stats_TEAM.csv")
euro_2012_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_2012_data.columns #displays all the column names
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
pd.set_option("display.max_columns", None) 
# displays all columns with data
# this should not be used. if excel is having more columns, it will take more time to load

# %%
euro_2012_data["Team"] #Filter and display single column
# Out:
# 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object

# %% [markdown]
# ### Chapter: 4 Filter the data with few particular columln and sort based on Yellow Cards

# %%
filtered_euro_data = euro_2012_data[["Team","Goals", "Red Cards", "Yellow Cards"]] #Filter and display multiple column
filtered_euro_data.sort_values(by="Yellow Cards",ascending=False)
# Out:
#                    Team  Goals  Red Cards  Yellow Cards
# 7                 Italy      6          0            16
# 10             Portugal      6          0            12
# 13                Spain     12          0            11
# 0               Croatia      4          0             9
# 6                Greece      5          1             9
# 14               Sweden      5          0             7
# 9                Poland      2          1             7
# 1        Czech Republic      4          0             7
# 12               Russia      5          0             6
# 11  Republic of Ireland      1          1             6
# 4                France      3          0             6
# 3               England      5          0             5
# 8           Netherlands      2          0             5
# 15              Ukraine      2          0             5
# 5               Germany     10          0             4
# 2               Denmark      4          0             4

# %% [markdown]
# #### 4.1 Top 5 Yellow Card Team

# %%
filtered_euro_data.sort_values(by="Yellow Cards", ascending=False).head(5)
# Out:
#         Team  Goals  Red Cards  Yellow Cards
# 7      Italy      6          0            16
# 10  Portugal      6          0            12
# 13     Spain     12          0            11
# 0    Croatia      4          0             9
# 6     Greece      5          1             9

# %% [markdown]
# #### 4.2 List the teams which has Red Cards

# %%
filtered_euro_data[filtered_euro_data["Red Cards"] == 1]
# Out:
#                    Team  Goals  Red Cards  Yellow Cards
# 6                Greece      5          1             9
# 9                Poland      2          1             7
# 11  Republic of Ireland      1          1             6

# %% [markdown]
# #### 4.3 List the teams which has more than 8 Yellow Cards

# %%
filtered_euro_data[filtered_euro_data["Yellow Cards"] >= 8]
# Out:
#         Team  Goals  Red Cards  Yellow Cards
# 0    Croatia      4          0             9
# 6     Greece      5          1             9
# 7      Italy      6          0            16
# 10  Portugal      6          0            12
# 13     Spain     12          0            11

# %% [markdown]
# ## Task
# * Find out 5 questions with script answers

# %% [markdown]
# #### Display all the team in decending order

# %%
euro_2012_data.sort_values(by = 'Team', ascending=False)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 15              Ukraine      2                7                26
# 14               Sweden      5               17                19
# 13                Spain     12               42                33
# 12               Russia      5                9                31
# 11  Republic of Ireland      1                7                12
# 10             Portugal      6               22                42
# 9                Poland      2               15                23
# 8           Netherlands      2               12                36
# 7                 Italy      6               34                45
# 6                Greece      5                8                18
# 5               Germany     10               32                32
# 4                France      3               22                24
# 3               England      5               11                18
# ...

# %% [markdown]
# #### Use the same script and store the same in same variable instead of using = operator

# %%
#inplace attribute stores the modified data in the same variable
euro_2012_data.sort_values(by = 'Team', ascending=False, inplace=True)
euro_2012_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 15              Ukraine      2                7                26
# 14               Sweden      5               17                19
# 13                Spain     12               42                33
# 12               Russia      5                9                31
# 11  Republic of Ireland      1                7                12
# 10             Portugal      6               22                42
# 9                Poland      2               15                23
# 8           Netherlands      2               12                36
# 7                 Italy      6               34                45
# 6                Greece      5                8                18
# 5               Germany     10               32                32
# 4                France      3               22                24
# 3               England      5               11                18
# ...

# %% [markdown]
# ## Chapter 5: How to deal with Missing value

# %%
employee_data = pd.read_csv("employee_data.csv")
employee_data
#employee_data.drop_duplicates
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020

# %% [markdown]
# ### Always recommended : Call to my client and check with him if he can give the right data - Great!!!
#
# Incase, client is asking us to perform the Data cleaning Operations.

# %% [markdown]
# #### Step 1: Remove Duplicate entries/records:

# %%
employee_data.drop_duplicates(inplace=True) #Used inplace to update on the same employee_data
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %% [markdown]
# #### Step 2: Find Out the Null entries

# %%
employee_data.isnull().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        1
# Join_Date     0
# dtype: int64

# %%
employee_data.shape
# Out:
# (7, 5)

# %%
employee_data.dropna(inplace=True)
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023

# %%
employee_data.shape
# Out:
# (4, 5)

# %% [markdown]
# #### Step 3: Record in a document
#
# * Client gave totally 7 observations out of which 3 entries are removed because those records do not have complete information.
# #### Step 4: Get Approval
# * Send this to client and get the approval to proceed for Model Building or Model Training

# %%
employee_data.isnull().sum()
# Out:
# Name          0
# Age           0
# Department    0
# Salary        0
# Join_Date     0
# dtype: int64

# %% [markdown]
# ### Level 2 Data Cleaning:

# %%
pd.read_csv("employee_data.csv") 
# For Read CSV You can't import multiple sheets. You have to separate each sheet to each .csv files
# For Read Excel You can import multiple sheets
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020
