# %% [markdown]
# # Number Guessing Game Level

# %% [markdown]
# ### Print if the user guessed number is right or wrong

# %%
user_input = input("Enter the guessing number")
print(f'User Guessed number is {user_guessed_no}')
# Out:
# Enter the guessing number 11
# User Guessed number is 10
