# %% [markdown]
# ### Why Python Built-In Data Structure?
# * To collect multiple data in a structure

# %% [markdown]
# #### 4 Data Structures in Python
# 1. List
# 2. Sets
# 3. Tuples
# 4. Dictonary - key & value

# %% [markdown]
# #### 1. List
#
# - 1 Dimension
# - Hetrogenous
# - Duplicate Values
# - Indexing is possible
# - Slicing is possible
# - Mutable

# %%
empty_cart = []

# %%
empty_cart
# Out:
# []

# %%
type(empty_cart)
# Out:
# list

# %%
items_to_buy = ["Apple", "Orange", "Grapes", "Pomogranate", "Apple", 6.75, 8, True]

# %%
items_to_buy
# Out:
# ['Apple', 'Orange', 'Grapes', 'Pomogranate', 'Apple', 6.75, 8, True]

# %%
items_to_buy[2] #Indexing starts with 0 from left to right
# Out:
# 'Grapes'

# %%
items_to_buy[-1] #Indexing starts with -1 from right to left
# Out:
# True

# %%
len(items_to_buy)
# Out:
# 8

# %%
items_to_buy[1:4] #Slicing
# Out:
# ['Orange', 'Grapes', 'Pomogranate']

# %%
items_to_buy[-5:-2] # Reverse Slicing
# Out:
# ['Pomogranate', 'Apple', 6.75]

# %%
items_to_buy[2] = "Watermelon" #Mutable

# %%
items_to_buy
# Out:
# ['Apple', 'Orange', 'Watermelon', 'Pomogranate', 'Apple', 6.75, 8, True]

# %% [raw]
# #### 2. Sets
#
# - 1 Dimension
# - Hetrogenous
# - It won't allow duplicate values
# - Indexing and Slicing is not possible
# - Mutable

# %%
empty_set = set()

# %%
empty_set
# Out:
# set()

# %%
items_to_buy_2 = {"Apple", "Orange", "Grapes", "Pomogranate", "Apple", 6.75, 8, True}

# %%
items_to_buy_2
# Out:
# {6.75, 8, 'Apple', 'Grapes', 'Orange', 'Pomogranate', True}

# %%
items_to_buy_2.add("Bananna")
items_to_buy_2
# Out:
# {6.75, 8, 'Apple', 'Bananna', 'Grapes', 'Orange', 'Pomogranate', True}
