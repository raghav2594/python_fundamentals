# %% [markdown]
# # Example for Python Datastructure

# %% [markdown]
# ## Create DataFrame from Panda

# %%
team_details = {"QReport" : ["Raghav","Saravana"],
               "PCC" : ["Raghav","Saravana"],
               "Doc" : ["Milank","Saravana"]}
import pandas as pd
pd.DataFrame(data = team_details)
# Out:
#     QReport       PCC       Doc
# 0    Raghav    Raghav    Milank
# 1  Saravana  Saravana  Saravana
