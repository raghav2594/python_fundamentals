# %%
print("hi")
# Out:
# hi

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # Heading1

# %% [markdown]
# ## Heading2

# %% [markdown]
# ### Heading3

# %% [markdown]
# #### Heading4

# %% [markdown]
# ###### Heading5

# %%
x = "Python"
print("Learning",x)
# Out:
# Learning Python

# %%
num = "50"
print(int(num)+10)
# Out:
# 60

# %%
str = "raghavendar"

# %%
str.capitalize()
# Out:
# 'Raghavendar'

# %%
str.casefold()
# Out:
# 'raghavendar'

# %%
str.center(30)
# Out:
# '         raghavendar          '

# %%
len(str)
# Out:
# 11

# %%
str.index('g')
# Out:
# 2

# %%
str.isalpha()
# Out:
# True

# %%
str.isalnum()
# Out:
# True
