# %% [markdown]
# # Chapter 1

# %% [markdown]
# ## Variables

# %%
print("Hi Welocome to Nasirs Class")
# Out:
# Hi Welocome to Nasirs Class

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
$a=10
# Out:
#   Cell In[22], line 1
#     $a=10
#     ^
# SyntaxError: invalid syntax

# %%
_a=20

# %%
_a
# Out:
# 20

# %%
2a=50
# Out:
#   Cell In[25], line 1
#     2a=50
#     ^
# SyntaxError: invalid decimal literal

# %%
a2=50

# %%
a2
# Out:
# 50

# %%
_2a=50

# %%
_2a
# Out:
# 50

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print(A)
#
# NameError: name 'A' is not defined

# %%
a=200
b=3000
a
b
# Out:
# 3000

# %%
price=10

# %%
print(f'{price} $' )
# Out:
# 10 $

# %%
# Addition 
a=10
b=20
sum=a+b

# %%
#  print()

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
# print("A")

# %%
b=1.5

# %%
type(b)
# Out:
# float

# %%
type(a<b)
# Out:
# bool

# %%
print('Nasir's class is boooooring')
# Out:
#   Cell In[50], line 1
#     print('Nasir's class is boooooring')
#                                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello world')
# Out:
# Hello world

# %%
print("Nasir's class is boooooring")
# Out:
# Nasir's class is boooooring

# %%
print('''"Nasir" class is Good''')
# Out:
# "Nasir" class is Good

# %%
First_name='Bindu'

# %%
Last_name="Dk"

# %%
First_name=First_name.upper()

# %%
First_name
# Out:
# 'BINDU'

# %%
First_name.lower()
# Out:
# 'bindu'

# %%
Nasir is teaching bad nasir is bad very bad

# %%
First_name.count('n')
# Out:
# 0

# %%
First_name
# Out:
# 'BINDU'

# %%
First_name.count('N')
# Out:
# 1

# %%
First_name,Last_name
# Out:
# ('BINDU', 'Dk')

# %%
Full_Name=First_name,Last_name

# %%
Full_Name
# Out:
# ('BINDU', 'Dk')

# %%
Full_Name=First_name + " " + Last_name

# %%
Full_Name
# Out:
# 'Bindu Dk'

# %%
Full_Name[0]
# Out:
# 'B'

# %%
Full_Name[4]
# Out:
# 'u'

# %%
Full_Name[5]
# Out:
# ' '

# %%
Full_Name[7]
# Out:
# 'k'

# %%
Full_Name[-1]
# Out:
# 'k'

# %%
Full_Name[-1]
# Out:
# 'u'

# %%
Full_Name[5:]
# Out:
# ' Dk'

# %%
Full_Name[:6]
# Out:
# 'Bindu '

# %%
Full_Name[:8]
# Out:
# 'Bindu Dk'

# %%
Full_Name[1:6]
# Out:
# 'indu '

# %%
First_name
# Out:
# 'Bindu'

# %%
First_name.upper()
# Out:
# 'BINDU'

# %% [markdown]
# # Operators

# %%
a=10
b=20

# %%
a+b
# Out:
# 30

# %%
a==10
# Out:
# True

# %%
a=a+b
a
# Out:
# 30

# %%
a
# Out:
# 20

# %%
b
# Out:
# 20

# %%
a+=b

# %%
a
# Out:
# 40

# %%
x=["a",'b',"c"]
y=["a","c"]

# %%
x is y
# Out:
# False

# %%
"z" in x
# Out:
# False

# %%
def

# %%
in or and

# %%
and

# %%
a=10
b=20
sum=a+b
print(sum)
# Out:
# 30

# %%
a=input("Enter the first num")
b=input("Enter the second num")

sum=a+b

print(sum)
# Out:
# Enter the first num10
# Enter the second num50
# 1050

# %%
a=int(input("Enter the first num"))
b=int(input("Enter the second num"))

sum=a+b

print(sum)
# Out:
# Enter the first num10
# Enter the second num50
# 60

# %%
a=input("Enter the first num")
b=input("Enter the second num")

sum=int(a)+int(b)

print(sum)
# Out:
# Enter the first num10
# Enter the second num20
# 30

# %%
First_name="Divya"

# %%
Last_name="Prakash"

# %%
Full_name=First_name+ " "+Last_name

# %%
Full_name
# Out:
# 'Divya Prakash'

# %%
print('Welcome'+" "+ Full_name+" "+"to Nasir class")
# Out:
# Welcome Divya Prakash to Nasir class

# %%
print('Welcome',Full_name,"to Nasir class")
# Out:
# Welcome Divya Prakash to Nasir class

# %%
print(f"Welcome {Full_name} to Nasir's Class")
# Out:
# Welcome Divya Prakash to Nasir's Class

# %%
age=12

# %%
print(f"Welcome {Full_name} to Nasir's Class you are {age} years old ")
# Out:
# Welcome Divya Prakash to Nasir's Class you are 12 years old

# %%
name = input(" Please enter your name: ")
age = int(input( " Please enter your age: "))
print(f"Hello {name} you will be {age +20} after 20 years")
# Out:
#  Please enter your name: Nasir
#  Please enter your age: 20
# Hello Nasir you will be 40 after 20 years

# %%
name=input("enter your name")
age=int(input("enter your age"))

print(f"hi {name} {age+20}")
# Out:
# enter your nameNASIR aLI
# enter your age20
# hiNASIR aLI 40

# %%
Name=input("Enter the name ")
age=int(input("Enter the age"))
print(f"Hi {Name} after 10 years you will be {age+10} years old"  )
# Out:
# Enter the name Nasir
# Enter the age20
# Hi Nasir after 10 years you will be 30 years old

# %%
name=input("please enter your name")
age=int(input("please enter your age "))
print(f"hi {name} after ten years you will be {age + 10} years")
# Out:
# please enter your nameNikitha
# please enter your age 10
# hi Nikitha  after ten years you will be 20 years

# %%
first_name=input("Enter your First Name- ")
last_name=input("Enter your Last Name- ")
age=int(input("Enter your age- "))
full_name=(first_name + " " + last_name)

print(f"Hello {full_name} welcome to nasir's class your are {age} years old and you'll be {age+20} in 20 years")
# Out:
# Enter your First Name- Nas
# Enter your Last Name- ir
# Enter your age- 20
# Hello Nas ir welcome to nasir's class your are 20 years old and you'll be 40 in 20 years

# %%
name=input("Enter your name")
age=int(input("enter your age"))
age=age+10
print(f"Hi {name} after 10 yeras will be + {age} year old")
# Out:
# Enter your nameNas
# enter your age10
# Hi Nas after 10 yeras will be + 20 year old

# %%
Name=input("Enter the name")
age=input("Enter the age")
print(f"hi {Name} after 10 year you will be {int(age)+10} year")
# Out:
# Enter the namenasir
# Enter the age10
# hi nasir after 10 year you will be 20 year
