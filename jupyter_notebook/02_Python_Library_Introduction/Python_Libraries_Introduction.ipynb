# %% [markdown]
# ## Libraries
#
# It is a set of functions, modules and classess where it has pre-written codes to perform some task

# %% [markdown]
# ## 1. Pandas Library
# - For data analysis

# %%
pip install pandas
# Out:
# ...
#                                               0.0/11.3 MB ? eta -:--:--
#                                               0.0/11.3 MB ? eta -:--:--
#                                               0.0/11.3 MB ? eta -:--:--
#                                               0.0/11.3 MB ? eta -:--:--
#                                               0.0/11.3 MB ? eta -:--:--
#                                               0.0/11.3 MB ? eta -:--:--
#                                               0.0/11.3 MB ? eta -:--:--
#                                               0.0/11.3 MB ? eta -:--:--
#                                               0.0/11.3 MB ? eta -:--:--
#                                               0.0/11.3 MB ? eta -:--:--
#                                              0.0/11.3 MB 151.3 kB/s eta 0:01:15
#                                              0.0/11.3 MB 151.3 kB/s eta 0:01:15
#                                              0.0/11.3 MB 151.3 kB/s eta 0:01:15
# ...

# %% [markdown]
# #### Import Pandas

# %%
import pandas as pd
# pip means 'Preferred Installer Program'

# %% [markdown]
# ### Read csv file from python code

# %%
employee_data = pd.read_csv('employees.csv')

# %%
employee_data
# Out:
#      EmployeeID          Name Department  Salary JoiningDate
# 0           101  Employee_101    Finance   69148  2023-06-18
# 1           102  Employee_102  Marketing   62598  2022-09-28
# 2           103  Employee_103         HR   63802  2018-01-18
# 3           104  Employee_104      Sales   76874  2021-09-23
# 4           105  Employee_105    Finance   47209  2023-09-14
# ..          ...           ...        ...     ...         ...
# 145         246  Employee_246  Marketing  105735  2018-04-05
# 146         247  Employee_247         HR   65735  2019-10-23
# 147         248  Employee_248  Marketing   83796  2024-02-20
# 148         249  Employee_249      Sales   69213  2023-08-14
# 149         250  Employee_250         HR   78348  2021-05-28
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 2. Numpy Library
# - For Math and Array operations
# - Basically playing with numbers
# The NumPy library is installed automatically when you install Pandas.

# %%
import numpy as np

# %%
employee_repeated_data = np.repeat(a = employee_data,repeats = 2, axis= 0)
# Arguments information
# a - it can be a dataset might be an array or pandas dataset
# repeats - how many times want to repeat?
# axis - It should be repeated in column or rows
   # axis = 0 for repeating in rows
   # axis = 1 for repeating in columns

# %%
pd.DataFrame(data = employee_repeated_data)
#A Pandas DataFrame is a two-dimensional, tabular data structure in Python provided by the Pandas library.
#It’s similar to a spreadsheet or SQL table and is one of the most powerful tools for data analysis.
# Out:
#        0             1          2      3           4
# 0    101  Employee_101    Finance  69148  2023-06-18
# 1    101  Employee_101    Finance  69148  2023-06-18
# 2    102  Employee_102  Marketing  62598  2022-09-28
# 3    102  Employee_102  Marketing  62598  2022-09-28
# 4    103  Employee_103         HR  63802  2018-01-18
# ..   ...           ...        ...    ...         ...
# 295  248  Employee_248  Marketing  83796  2024-02-20
# 296  249  Employee_249      Sales  69213  2023-08-14
# 297  249  Employee_249      Sales  69213  2023-08-14
# 298  250  Employee_250         HR  78348  2021-05-28
# 299  250  Employee_250         HR  78348  2021-05-28
#
# [300 rows x 5 columns]

# %% [markdown]
# ### 3 Matplotlib, Seaborn, Plotly
# - Data Visualization Libraries

# %%
pip install matplotlib
# Out:
# ...
#                                               0.0/8.1 MB ? eta -:--:--
#                                               0.0/8.1 MB ? eta -:--:--
#                                               0.0/8.1 MB ? eta -:--:--
#                                               0.0/8.1 MB ? eta -:--:--
#                                               0.0/8.1 MB ? eta -:--:--
#                                               0.0/8.1 MB ? eta -:--:--
#                                               0.0/8.1 MB ? eta -:--:--
#                                               0.0/8.1 MB ? eta -:--:--
#                                               0.0/8.1 MB ? eta -:--:--
#                                               0.0/8.1 MB 140.3 kB/s eta 0:00:58
#                                               0.0/8.1 MB 140.3 kB/s eta 0:00:58
#                                               0.0/8.1 MB 140.3 kB/s eta 0:00:58
#                                               0.0/8.1 MB 140.3 kB/s eta 0:00:58
# ...

# %%
from matplotlib import pyplot as plt
# import matplotlib.pyplot as plt (This is also possible)

# %%
plt.hist(x = employee_data.Salary)

#almost similar for seaborn and p
# Out:
# (array([16., 15., 12., 20., 14., 24., 10., 17., 14.,  8.]),
#  array([ 40478. ,  48347.1,  56216.2,  64085.3,  71954.4,  79823.5,
#          87692.6,  95561.7, 103430.8, 111299.9, 119169. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 2 Types of datatypes:
# 1. Discrete - Countable, it will never have units, you can't measure that
# 2. Continous - It will have units, it is measurable
